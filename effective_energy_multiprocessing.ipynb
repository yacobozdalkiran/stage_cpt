# %%
from masse_effective_pion_fonctions_mod import jacknife
import concurrent.futures

# %%
def jack_pion(config):
    list_data = []
    chonologie = []
    if config == "5S5S":
        list_data = ["./data/pion-g5-S,0,1,0,0,1,1,0,0,0.pion-g5-S,0.px0_py0_pz"+ str(i) + ".m-0.3303_m-0.3303.n3.dat" for i in range(-8, 9)]
    if config == "5S5P":
        list_data = ["./data/pion-g5-S,0,1,0,0,1,1,0,0,0.pion-g5-P,0.px0_py0_pz"+ str(i) + ".m-0.3303_m-0.3303.n3.dat" for i in range(-8, 9)]
    if config == "5S45S":
        list_data = ["./data/pion-g5-S,0,1,0,0,1,1,0,0,0.pion-g45-S,0.px0_py0_pz"+ str(i) + ".m-0.3303_m-0.3303.n3.dat" for i in range(-8, 9)]
    if config == "5S45P":
        list_data = ["./data/pion-g5-S,0,1,0,0,1,1,0,0,0.pion-g45-P,0.px0_py0_pz"+ str(i) + ".m-0.3303_m-0.3303.n3.dat" for i in range(-8, 9)]
    if config == "45S5S":
        list_data = ["./data/pion-g45-S,0,1,0,0,1,1,0,0,0.pion-g5-S,0.px0_py0_pz"+ str(i) + ".m-0.3303_m-0.3303.n3.dat" for i in range(-8, 9)]
    if config == "45S5P":
        list_data = ["./data/pion-g45-S,0,1,0,0,1,1,0,0,0.pion-g5-P,0.px0_py0_pz"+ str(i) + ".m-0.3303_m-0.3303.n3.dat" for i in range(-8, 9)]
    if config == "45S45S":
        list_data = ["./data/pion-g45-S,0,1,0,0,1,1,0,0,0.pion-g45-S,0.px0_py0_pz"+ str(i) + ".m-0.3303_m-0.3303.n3.dat" for i in range(-8, 9)]
    if config == "45S45P":
        list_data = ["./data/pion-g45-S,0,1,0,0,1,1,0,0,0.pion-g45-P,0.px0_py0_pz"+ str(i) + ".m-0.3303_m-0.3303.n3.dat" for i in range(-8, 9)]
    E0_config = [config]
    E0unb_config = [config]
    sigmajn_config = [config]
    for fichier in list_data:
        print("Estimation de l'énergie effective de " + fichier)
        a=0.0652
        x=3026.4877
        nconf=999
        E0jn, E0, E0unb, sigmajn = jacknife(nconf,fichier, a, x)
        E0_config.append(E0)
        E0unb_config.append(E0unb)
        sigmajn_config.append(sigmajn)
    donnees = np.array(list(zip(E0_config, E0unb_config, sigmajn_config)))
    np.savetxt(config+'.dat', donnees, fmt='%.2f', delimiter='\t')
    return E0_config, E0unb_config, sigmajn_config

# %%
args_list = ["5S5S", "5S5P", "5S45S", "5S45P", "45S5S", "45S5P", "45S45S", "45S45P"]
nombre_threads = len(args_list)

# %%
with concurrent.futures.ThreadPoolExecutor(max_workers=nombre_threads) as executor:
    results = executor.map(jack_pion, args_list)
# Out:
# Estimation de l'énergie effective de ./data/pion-g5-S,0,1,0,0,1,1,0,0,0.pion-g5-S,0.px0_py0_pz-8.m-0.3303_m-0.3303.n3.dat
# Estimation de l'énergie effective de ./data/pion-g5-S,0,1,0,0,1,1,0,0,0.pion-g5-P,0.px0_py0_pz-8.m-0.3303_m-0.3303.n3.dat
# Estimation de l'énergie effective de ./data/pion-g5-S,0,1,0,0,1,1,0,0,0.pion-g45-S,0.px0_py0_pz-8.m-0.3303_m-0.3303.n3.dat
# Estimation de l'énergie effective de ./data/pion-g5-S,0,1,0,0,1,1,0,0,0.pion-g45-P,0.px0_py0_pz-8.m-0.3303_m-0.3303.n3.dat
# Estimation de l'énergie effective de ./data/pion-g45-S,0,1,0,0,1,1,0,0,0.pion-g5-S,0.px0_py0_pz-8.m-0.3303_m-0.3303.n3.dat
# Estimation de l'énergie effective de ./data/pion-g45-S,0,1,0,0,1,1,0,0,0.pion-g5-P,0.px0_py0_pz-8.m-0.3303_m-0.3303.n3.dat
# Estimation de l'énergie effective de ./data/pion-g45-S,0,1,0,0,1,1,0,0,0.pion-g45-S,0.px0_py0_pz-8.m-0.3303_m-0.3303.n3.dat
# Estimation de l'énergie effective de ./data/pion-g45-S,0,1,0,0,1,1,0,0,0.pion-g45-P,0.px0_py0_pz-8.m-0.3303_m-0.3303.n3.dat
# ...
